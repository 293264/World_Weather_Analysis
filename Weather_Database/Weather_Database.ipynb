# %%
# Import dependenncies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
from citipy import citipy
from datetime import datetime
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create API URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | conde
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | laguna
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | inuvik
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | roma
# Processing Record 18 of Set 1 | ancud
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | kurumkan
# Processing Record 21 of Set 1 | kloulklubed
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | talcahuano
# Processing Record 27 of Set 1 | bogorodskoye
# Processing Record 28 of Set 1 | sakakah
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | san francisco
# Processing Record 31 of Set 1 | petropavlovka
# Processing Record 32 of Set 1 | ola
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | starodub
# Processing Record 37 of Set 1 | xingyi
# Processing Record 38 of Set 1 | merauke
# Processing Record 39 of Set 1 | raahe
# Processing Record 40 of Set 1 | el alto
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | faya
# Processing Record 43 of Set 1 | tazovskiy
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | ketchikan
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | lac du bonnet
# Processing Record 2 of Set 2 | port hedland
# Processing Record 3 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 2 | vuktyl
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | yanam
# Processing Record 7 of Set 2 | shingu
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | taksimo
# Processing Record 10 of Set 2 | tucurui
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 14 of Set 2 | shirokiy
# Processing Record 15 of Set 2 | denpasar
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | sur
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | yar-sale
# Processing Record 22 of Set 2 | grindavik
# Processing Record 23 of Set 2 | loreto
# Processing Record 24 of Set 2 | beaverlodge
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | san quintin
# Processing Record 30 of Set 2 | dhanaura
# Processing Record 31 of Set 2 | ocotal
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | san jose
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | salalah
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | sheltozero
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | ulyanovsk
# Processing Record 43 of Set 2 | bell ville
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | zheshart
# Processing Record 46 of Set 2 | baglan
# Processing Record 47 of Set 2 | dakar
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | prado
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | naryan-mar
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | comodoro rivadavia
# Processing Record 9 of Set 3 | hailey
# Processing Record 10 of Set 3 | paamiut
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | warrnambool
# Processing Record 14 of Set 3 | mendi
# Processing Record 15 of Set 3 | biloela
# Processing Record 16 of Set 3 | constitucion
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | bilibino
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | necochea
# Processing Record 24 of Set 3 | hsinchu
# Processing Record 25 of Set 3 | guerrero negro
# Processing Record 26 of Set 3 | mopti
# Processing Record 27 of Set 3 | aykhal
# Processing Record 28 of Set 3 | itamaraca
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | nemuro
# Processing Record 31 of Set 3 | mount isa
# Processing Record 32 of Set 3 | ipameri
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | marsaxlokk
# Processing Record 36 of Set 3 | ayagoz
# Processing Record 37 of Set 3 | clinton
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | vilaka
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 3 | san juan
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | gizo
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | caiaponia
# Processing Record 48 of Set 3 | khuzhir
# Processing Record 49 of Set 3 | havoysund
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | tessalit
# Processing Record 2 of Set 4 | chumikan
# Processing Record 3 of Set 4 | diego de almagro
# Processing Record 4 of Set 4 | okhotsk
# Processing Record 5 of Set 4 | moree
# Processing Record 6 of Set 4 | garhshankar
# Processing Record 7 of Set 4 | the valley
# Processing Record 8 of Set 4 | japura
# Processing Record 9 of Set 4 | shihezi
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | awbari
# Processing Record 12 of Set 4 | locri
# Processing Record 13 of Set 4 | ust-nera
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | ngunguru
# Processing Record 16 of Set 4 | portland
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | tanete
# Processing Record 19 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | lakselv
# Processing Record 25 of Set 4 | flinders
# Processing Record 26 of Set 4 | parras
# City not found. Skipping...
# Processing Record 27 of Set 4 | kolokani
# Processing Record 28 of Set 4 | midland
# Processing Record 29 of Set 4 | kavieng
# Processing Record 30 of Set 4 | la trinidad
# Processing Record 31 of Set 4 | sorland
# Processing Record 32 of Set 4 | poum
# Processing Record 33 of Set 4 | ranong
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 4 | sola
# Processing Record 37 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 4 | ndjole
# Processing Record 39 of Set 4 | pizarro
# Processing Record 40 of Set 4 | wazzan
# City not found. Skipping...
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | dandong
# Processing Record 45 of Set 4 | avera
# Processing Record 46 of Set 4 | avdiyivka
# Processing Record 47 of Set 4 | hondo
# Processing Record 48 of Set 4 | road town
# Processing Record 49 of Set 4 | jieshi
# Processing Record 50 of Set 4 | avdon
# Processing Record 1 of Set 5 | uyuni
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | tarauaca
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | satao
# Processing Record 8 of Set 5 | san luis
# Processing Record 9 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 10 of Set 5 | ixtapa
# Processing Record 11 of Set 5 | walvis bay
# Processing Record 12 of Set 5 | yingkou
# Processing Record 13 of Set 5 | biak
# Processing Record 14 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | minudasht
# Processing Record 18 of Set 5 | tonstad
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | kodiak
# Processing Record 21 of Set 5 | araouane
# Processing Record 22 of Set 5 | novouzensk
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | port hueneme
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | alamor
# Processing Record 27 of Set 5 | havre-saint-pierre
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | kassala
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | coquimbo
# Processing Record 32 of Set 5 | maketu
# Processing Record 33 of Set 5 | tiksi
# Processing Record 34 of Set 5 | mikhaylovka
# Processing Record 35 of Set 5 | ahipara
# Processing Record 36 of Set 5 | ilulissat
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | bubaque
# Processing Record 39 of Set 5 | voh
# Processing Record 40 of Set 5 | ambilobe
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | opuwo
# Processing Record 43 of Set 5 | vestmanna
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | huesca
# Processing Record 46 of Set 5 | nhulunbuy
# Processing Record 47 of Set 5 | noumea
# Processing Record 48 of Set 5 | muros
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | namatanai
# Processing Record 1 of Set 6 | ciudad bolivar
# Processing Record 2 of Set 6 | buala
# Processing Record 3 of Set 6 | seryshevo
# Processing Record 4 of Set 6 | penzance
# Processing Record 5 of Set 6 | havelock
# Processing Record 6 of Set 6 | otane
# Processing Record 7 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 6 | naze
# Processing Record 9 of Set 6 | juazeiro
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 12 of Set 6 | tateyama
# Processing Record 13 of Set 6 | morro da fumaca
# Processing Record 14 of Set 6 | seydi
# Processing Record 15 of Set 6 | east london
# Processing Record 16 of Set 6 | kurilsk
# Processing Record 17 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 6 | don sak
# Processing Record 19 of Set 6 | aklavik
# Processing Record 20 of Set 6 | bacolod
# Processing Record 21 of Set 6 | sukumo
# Processing Record 22 of Set 6 | san cristobal
# Processing Record 23 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 6 | dudinka
# Processing Record 25 of Set 6 | katsuura
# Processing Record 26 of Set 6 | egvekinot
# Processing Record 27 of Set 6 | kedrovyy
# Processing Record 28 of Set 6 | nam som
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | kalga
# Processing Record 31 of Set 6 | antalaha
# Processing Record 32 of Set 6 | leh
# Processing Record 33 of Set 6 | vangaindrano
# Processing Record 34 of Set 6 | conchal
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | dingle
# Processing Record 37 of Set 6 | solnechnyy
# Processing Record 38 of Set 6 | berdigestyakh
# Processing Record 39 of Set 6 | mogadishu
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 6 | lima
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | kushiro
# Processing Record 46 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 6 | neiafu
# Processing Record 49 of Set 6 | plattsburgh
# Processing Record 50 of Set 6 | chuy
# Processing Record 1 of Set 7 | nome
# Processing Record 2 of Set 7 | kainantu
# Processing Record 3 of Set 7 | palencia
# Processing Record 4 of Set 7 | kieta
# Processing Record 5 of Set 7 | saint-louis
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | nuuk
# Processing Record 8 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 7 | halifax
# Processing Record 10 of Set 7 | vagay
# Processing Record 11 of Set 7 | samut sakhon
# Processing Record 12 of Set 7 | camopi
# Processing Record 13 of Set 7 | rafai
# Processing Record 14 of Set 7 | tual
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | kununurra
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | kamphaeng phet
# Processing Record 19 of Set 7 | teshie
# Processing Record 20 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | chicama
# Processing Record 23 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint anthony
# Processing Record 25 of Set 7 | palaikastron
# Processing Record 26 of Set 7 | zhengjiatun
# Processing Record 27 of Set 7 | ierapetra
# Processing Record 28 of Set 7 | mahajanga
# Processing Record 29 of Set 7 | holme
# Processing Record 30 of Set 7 | kachug
# Processing Record 31 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | abu samrah
# Processing Record 34 of Set 7 | marfino
# Processing Record 35 of Set 7 | kalianget
# Processing Record 36 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 7 | kerman
# Processing Record 38 of Set 7 | skaerbaek
# Processing Record 39 of Set 7 | nuzvid
# Processing Record 40 of Set 7 | americus
# Processing Record 41 of Set 7 | high level
# Processing Record 42 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 43 of Set 7 | belmonte
# Processing Record 44 of Set 7 | cesenatico
# Processing Record 45 of Set 7 | gornopravdinsk
# Processing Record 46 of Set 7 | mount pleasant
# Processing Record 47 of Set 7 | mayo
# Processing Record 48 of Set 7 | omboue
# Processing Record 49 of Set 7 | campos
# Processing Record 50 of Set 7 | albania
# Processing Record 1 of Set 8 | steamboat springs
# Processing Record 2 of Set 8 | bossangoa
# Processing Record 3 of Set 8 | sembe
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | zhigansk
# Processing Record 8 of Set 8 | hosakote
# Processing Record 9 of Set 8 | mangai
# Processing Record 10 of Set 8 | krasnyy yar
# Processing Record 11 of Set 8 | codrington
# Processing Record 12 of Set 8 | acari
# Processing Record 13 of Set 8 | bridlington
# Processing Record 14 of Set 8 | nkayi
# Processing Record 15 of Set 8 | verkh-usugli
# Processing Record 16 of Set 8 | chapais
# Processing Record 17 of Set 8 | chemainus
# Processing Record 18 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | gweta
# Processing Record 21 of Set 8 | parrita
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | loubomo
# Processing Record 24 of Set 8 | gardabani
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | pontes e lacerda
# Processing Record 27 of Set 8 | maple creek
# Processing Record 28 of Set 8 | teahupoo
# Processing Record 29 of Set 8 | deputatskiy
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | staryy nadym
# Processing Record 32 of Set 8 | hamilton
# Processing Record 33 of Set 8 | mackay
# Processing Record 34 of Set 8 | nantucket
# Processing Record 35 of Set 8 | kihurio
# Processing Record 36 of Set 8 | kalmunai
# Processing Record 37 of Set 8 | khvorostyanka
# Processing Record 38 of Set 8 | adeje
# Processing Record 39 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 8 | dalvik
# Processing Record 41 of Set 8 | bratsk
# Processing Record 42 of Set 8 | ekibastuz
# Processing Record 43 of Set 8 | san jeronimo
# Processing Record 44 of Set 8 | benjamin constant
# Processing Record 45 of Set 8 | katherine
# Processing Record 46 of Set 8 | cortez
# Processing Record 47 of Set 8 | batemans bay
# Processing Record 48 of Set 8 | antofagasta
# Processing Record 49 of Set 8 | bonnyville
# Processing Record 50 of Set 8 | seymchan
# Processing Record 1 of Set 9 | aketi
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | onguday
# Processing Record 4 of Set 9 | cayenne
# Processing Record 5 of Set 9 | alpatovo
# Processing Record 6 of Set 9 | hervey bay
# Processing Record 7 of Set 9 | rybnoye
# Processing Record 8 of Set 9 | mildura
# Processing Record 9 of Set 9 | orbetello
# Processing Record 10 of Set 9 | riberalta
# Processing Record 11 of Set 9 | college
# Processing Record 12 of Set 9 | apollonia
# Processing Record 13 of Set 9 | praia
# Processing Record 14 of Set 9 | byron bay
# Processing Record 15 of Set 9 | gabu
# Processing Record 16 of Set 9 | imbituba
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | catamarca
# Processing Record 19 of Set 9 | asau
# Processing Record 20 of Set 9 | mananjary
# Processing Record 21 of Set 9 | champerico
# Processing Record 22 of Set 9 | broome
# Processing Record 23 of Set 9 | mbabane
# Processing Record 24 of Set 9 | samarai
# Processing Record 25 of Set 9 | koumac
# Processing Record 26 of Set 9 | beloha
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | shimoda
# Processing Record 30 of Set 9 | damietta
# Processing Record 31 of Set 9 | luena
# Processing Record 32 of Set 9 | odweyne
# Processing Record 33 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 9 | magdagachi
# Processing Record 35 of Set 9 | pierre
# Processing Record 36 of Set 9 | monduli
# Processing Record 37 of Set 9 | panaba
# Processing Record 38 of Set 9 | la ronge
# Processing Record 39 of Set 9 | sault sainte marie
# Processing Record 40 of Set 9 | neyshabur
# Processing Record 41 of Set 9 | broken hill
# Processing Record 42 of Set 9 | letterkenny
# Processing Record 43 of Set 9 | sabang
# Processing Record 44 of Set 9 | jalu
# Processing Record 45 of Set 9 | radnevo
# Processing Record 46 of Set 9 | katav-ivanovsk
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | burnie
# Processing Record 49 of Set 9 | marzuq
# Processing Record 50 of Set 9 | roald
# Processing Record 1 of Set 10 | soverato
# Processing Record 2 of Set 10 | moindou
# Processing Record 3 of Set 10 | hwange
# Processing Record 4 of Set 10 | tutoia
# Processing Record 5 of Set 10 | mosquera
# Processing Record 6 of Set 10 | roebourne
# Processing Record 7 of Set 10 | ladario
# Processing Record 8 of Set 10 | lasa
# Processing Record 9 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 10 | tuatapere
# Processing Record 11 of Set 10 | molepolole
# Processing Record 12 of Set 10 | istanbul
# Processing Record 13 of Set 10 | truth or consequences
# Processing Record 14 of Set 10 | villa bruzual
# Processing Record 15 of Set 10 | coffs harbour
# Processing Record 16 of Set 10 | lieksa
# Processing Record 17 of Set 10 | misratah
# Processing Record 18 of Set 10 | dingzhou
# Processing Record 19 of Set 10 | mandalgovi
# Processing Record 20 of Set 10 | cabo san lucas
# Processing Record 21 of Set 10 | port moresby
# Processing Record 22 of Set 10 | vardo
# Processing Record 23 of Set 10 | high rock
# Processing Record 24 of Set 10 | alofi
# Processing Record 25 of Set 10 | malartic
# Processing Record 26 of Set 10 | darhan
# Processing Record 27 of Set 10 | katubao
# Processing Record 28 of Set 10 | waddan
# Processing Record 29 of Set 10 | stornoway
# Processing Record 30 of Set 10 | hajipur
# Processing Record 31 of Set 10 | norfolk
# Processing Record 32 of Set 10 | borba
# Processing Record 33 of Set 10 | svirstroy
# Processing Record 34 of Set 10 | do gonbadan
# Processing Record 35 of Set 10 | sisimiut
# Processing Record 36 of Set 10 | senador guiomard
# Processing Record 37 of Set 10 | trelew
# Processing Record 38 of Set 10 | velyka mykhaylivka
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 41 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 10 | daru
# Processing Record 44 of Set 10 | sovetskiy
# Processing Record 45 of Set 10 | krasnovishersk
# Processing Record 46 of Set 10 | demidov
# Processing Record 47 of Set 10 | khorinsk
# Processing Record 48 of Set 10 | luanda
# Processing Record 49 of Set 10 | vikhorevka
# Processing Record 50 of Set 10 | iskateley
# Processing Record 1 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 11 | pisco
# Processing Record 3 of Set 11 | adrar
# Processing Record 4 of Set 11 | srimushnam
# Processing Record 5 of Set 11 | makaha
# Processing Record 6 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 11 | kaz
# Processing Record 8 of Set 11 | dale
# Processing Record 9 of Set 11 | dubbo
# Processing Record 10 of Set 11 | ulaangom
# Processing Record 11 of Set 11 | lagoa
# Processing Record 12 of Set 11 | oistins
# Processing Record 13 of Set 11 | soyo
# Processing Record 14 of Set 11 | sabha
# Processing Record 15 of Set 11 | gambela
# Processing Record 16 of Set 11 | uvat
# Processing Record 17 of Set 11 | kathu
# Processing Record 18 of Set 11 | peniche
# Processing Record 19 of Set 11 | eyl
# Processing Record 20 of Set 11 | presidente medici
# Processing Record 21 of Set 11 | zverinogolovskoye
# Processing Record 22 of Set 11 | gladstone
# Processing Record 23 of Set 11 | kysyl-syr
# Processing Record 24 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 11 | meulaboh
# Processing Record 26 of Set 11 | dera din panah
# City not found. Skipping...
# Processing Record 27 of Set 11 | abalak
# Processing Record 28 of Set 11 | altay
# Processing Record 29 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 11 | karatu
# Processing Record 31 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 11 | turukhansk
# Processing Record 33 of Set 11 | phan thiet
# Processing Record 34 of Set 11 | tahe
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | bagdarin
# Processing Record 38 of Set 11 | joao pinheiro
# Processing Record 39 of Set 11 | port pirie
# Processing Record 40 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 11 | immokalee
# Processing Record 42 of Set 11 | ponazyrevo
# Processing Record 43 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 11 | belaya gora
# Processing Record 45 of Set 11 | iglesias
# Processing Record 46 of Set 11 | becerril
# Processing Record 47 of Set 11 | aksarka
# Processing Record 48 of Set 11 | mundo nuevo
# Processing Record 49 of Set 11 | kaeo
# Processing Record 50 of Set 11 | poronaysk
# Processing Record 1 of Set 12 | cockburn town
# Processing Record 2 of Set 12 | tak
# Processing Record 3 of Set 12 | kiunga
# Processing Record 4 of Set 12 | kupang
# Processing Record 5 of Set 12 | berbera
# Processing Record 6 of Set 12 | tondano
# Processing Record 7 of Set 12 | coihaique
# Processing Record 8 of Set 12 | palana
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | saint-pierre
# Processing Record 11 of Set 12 | iquitos
# Processing Record 12 of Set 12 | tahta
# Processing Record 13 of Set 12 | goure
# Processing Record 14 of Set 12 | saint-junien
# Processing Record 15 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 16 of Set 12 | ladnun
# Processing Record 17 of Set 12 | vanderhoof
# Processing Record 18 of Set 12 | luebo
# Processing Record 19 of Set 12 | caravelas
# Processing Record 20 of Set 12 | simbahan
# Processing Record 21 of Set 12 | kantabanji
# Processing Record 22 of Set 12 | aplahoue
# Processing Record 23 of Set 12 | nortelandia
# Processing Record 24 of Set 12 | jiayuguan
# Processing Record 25 of Set 12 | acarau
# Processing Record 26 of Set 12 | culpeper
# Processing Record 27 of Set 12 | lata
# Processing Record 28 of Set 12 | acapulco
# Processing Record 29 of Set 12 | lapua
# Processing Record 30 of Set 12 | husavik
# Processing Record 31 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | homer
# Processing Record 33 of Set 12 | winslow
# Processing Record 34 of Set 12 | dickinson
# Processing Record 35 of Set 12 | manta
# Processing Record 36 of Set 12 | tautira
# Processing Record 37 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 12 | bathsheba
# Processing Record 39 of Set 12 | voznesenye
# Processing Record 40 of Set 12 | morondava
# Processing Record 41 of Set 12 | mkushi
# Processing Record 42 of Set 12 | deloraine
# Processing Record 43 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 12 | jaypur
# Processing Record 45 of Set 12 | norilsk
# Processing Record 46 of Set 12 | nalut
# Processing Record 47 of Set 12 | hay river
# Processing Record 48 of Set 12 | aanekoski
# Processing Record 49 of Set 12 | yumen
# Processing Record 50 of Set 12 | xiuyan
# Processing Record 1 of Set 13 | raudeberg
# Processing Record 2 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 13 | colesberg
# Processing Record 4 of Set 13 | naugachhia
# Processing Record 5 of Set 13 | kenora
# Processing Record 6 of Set 13 | myitkyina
# Processing Record 7 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 8 of Set 13 | korla
# Processing Record 9 of Set 13 | samfya
# Processing Record 10 of Set 13 | ponta delgada
# Processing Record 11 of Set 13 | losal
# Processing Record 12 of Set 13 | shenjiamen
# Processing Record 13 of Set 13 | oranjestad
# Processing Record 14 of Set 13 | shevchenkove
# Processing Record 15 of Set 13 | lock haven
# Processing Record 16 of Set 13 | baisha
# Processing Record 17 of Set 13 | lai
# Processing Record 18 of Set 13 | grayvoron
# Processing Record 19 of Set 13 | kapoeta
# Processing Record 20 of Set 13 | quetzaltepec
# City not found. Skipping...
# Processing Record 21 of Set 13 | quatre cocos
# Processing Record 22 of Set 13 | agadir
# Processing Record 23 of Set 13 | sao felix do xingu
# Processing Record 24 of Set 13 | yeppoon
# Processing Record 25 of Set 13 | zhanaozen
# Processing Record 26 of Set 13 | yazykovo
# Processing Record 27 of Set 13 | tarsus
# Processing Record 28 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | lovington
# Processing Record 30 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 13 | chateaudun
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 13 | qinhuangdao
# Processing Record 35 of Set 13 | mujiayingzi
# Processing Record 36 of Set 13 | priladozhskiy
# Processing Record 37 of Set 13 | kluczbork
# Processing Record 38 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 13 | asfi
# Processing Record 40 of Set 13 | mercedes
# Processing Record 41 of Set 13 | vavozh
# Processing Record 42 of Set 13 | yuksekova
# Processing Record 43 of Set 13 | margate
# Processing Record 44 of Set 13 | kildare
# Processing Record 45 of Set 13 | dannenberg
# Processing Record 46 of Set 13 | montepuez
# Processing Record 47 of Set 13 | gallup
# Processing Record 48 of Set 13 | puerto escondido
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | baherden
# Processing Record 1 of Set 14 | wajir
# Processing Record 2 of Set 14 | boguchany
# Processing Record 3 of Set 14 | perth
# Processing Record 4 of Set 14 | mitsamiouli
# Processing Record 5 of Set 14 | rawson
# Processing Record 6 of Set 14 | limbang
# Processing Record 7 of Set 14 | rock springs
# Processing Record 8 of Set 14 | oussouye
# Processing Record 9 of Set 14 | wynyard
# Processing Record 10 of Set 14 | henties bay
# Processing Record 11 of Set 14 | porto walter
# Processing Record 12 of Set 14 | victor harbor
# Processing Record 13 of Set 14 | cap malheureux
# Processing Record 14 of Set 14 | merrill
# Processing Record 15 of Set 14 | nosy varika
# Processing Record 16 of Set 14 | vao
# Processing Record 17 of Set 14 | itarema
# Processing Record 18 of Set 14 | okakarara
# Processing Record 19 of Set 14 | hvide sande
# Processing Record 20 of Set 14 | ambagarh chauki
# Processing Record 21 of Set 14 | nzerekore
# Processing Record 22 of Set 14 | panjab
# Processing Record 23 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 24 of Set 14 | kavaratti
# Processing Record 25 of Set 14 | dolores
# Processing Record 26 of Set 14 | port augusta
# Processing Record 27 of Set 14 | wajima
# Processing Record 28 of Set 14 | quelimane
# Processing Record 29 of Set 14 | challapata
# Processing Record 30 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 31 of Set 14 | selfoss
# Processing Record 32 of Set 14 | vagur
# Processing Record 33 of Set 14 | lernapat
# Processing Record 34 of Set 14 | cairo
# Processing Record 35 of Set 14 | napier
# Processing Record 36 of Set 14 | diffa
# Processing Record 37 of Set 14 | lensk
# Processing Record 38 of Set 14 | sao jose da coroa grande
# Processing Record 39 of Set 14 | pingliang
# Processing Record 40 of Set 14 | ryotsu
# Processing Record 41 of Set 14 | lithakia
# Processing Record 42 of Set 14 | istmina
# Processing Record 43 of Set 14 | jonkoping
# Processing Record 44 of Set 14 | sarakhs
# Processing Record 45 of Set 14 | zhanakorgan
# Processing Record 46 of Set 14 | atar
# Processing Record 47 of Set 14 | sioux lookout
# Processing Record 48 of Set 14 | mazamari
# Processing Record 49 of Set 14 | poddorye
# Processing Record 50 of Set 14 | tigil
# Processing Record 1 of Set 15 | jiexiu
# Processing Record 2 of Set 15 | gloucester
# Processing Record 3 of Set 15 | berezovyy
# Processing Record 4 of Set 15 | terrace
# Processing Record 5 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 15 | gold coast
# Processing Record 7 of Set 15 | matata
# Processing Record 8 of Set 15 | marawi
# Processing Record 9 of Set 15 | khorramshahr
# Processing Record 10 of Set 15 | okitipupa
# Processing Record 11 of Set 15 | kaa-khem
# Processing Record 12 of Set 15 | boende
# Processing Record 13 of Set 15 | prince george
# Processing Record 14 of Set 15 | ust-karsk
# Processing Record 15 of Set 15 | tilichiki
# Processing Record 16 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 15 | pontal do parana
# Processing Record 18 of Set 15 | krasnoselkup
# Processing Record 19 of Set 15 | weyburn
# Processing Record 20 of Set 15 | mindelo
# Processing Record 21 of Set 15 | salta
# Processing Record 22 of Set 15 | lodja
# Processing Record 23 of Set 15 | rovaniemi
# Processing Record 24 of Set 15 | sambava
# Processing Record 25 of Set 15 | athabasca
# Processing Record 26 of Set 15 | kiama
# Processing Record 27 of Set 15 | eirunepe
# Processing Record 28 of Set 15 | tura
# Processing Record 29 of Set 15 | banes
# Processing Record 30 of Set 15 | sodertalje
# City not found. Skipping...
# Processing Record 31 of Set 15 | mbini
# Processing Record 32 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 15 | plettenberg bay
# Processing Record 34 of Set 15 | nishihara
# Processing Record 35 of Set 15 | kandrian
# Processing Record 36 of Set 15 | costinesti
# Processing Record 37 of Set 15 | san buenaventura
# Processing Record 38 of Set 15 | turinsk
# Processing Record 39 of Set 15 | karpathos
# Processing Record 40 of Set 15 | nsoko
# Processing Record 41 of Set 15 | zhezkazgan
# Processing Record 42 of Set 15 | novikovo
# Processing Record 43 of Set 15 | svetlyy
# Processing Record 44 of Set 15 | chernukha
# Processing Record 45 of Set 15 | padang
# Processing Record 46 of Set 15 | saint-joseph
# Processing Record 47 of Set 15 | karoi
# Processing Record 48 of Set 15 | naranjal
# Processing Record 49 of Set 15 | tomatlan
# Processing Record 50 of Set 15 | moussoro
# Processing Record 1 of Set 16 | nouadhibou
# Processing Record 2 of Set 16 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     73.78        73           5
# 1         Conde  -7.2597  -34.9075     74.66        94          75
# 2      Thompson  55.7435  -97.8558     54.05        63          10
# 3    Bredasdorp -34.5322   20.0403     57.27        91          54
# 4        Laguna  38.4210 -121.4238     88.43        45           1
# 5   Port Alfred -33.5906   26.8910     64.96        88          32
# 6  Richards Bay -28.7830   32.0377     63.59        93          53
# 7        Inuvik  68.3499 -133.7218     31.75        89          95
# 8     Busselton -33.6500  115.3333     58.08        85          79
# 9       Mataura -46.1927  168.8643     48.47        37           4
#
#    Wind Speed Country Current Description
# 0       19.66      PF           clear sky
# 1       12.66      BR       broken clouds
# 2        2.10      CA           clear sky
# 3        1.48      ZA       broken clouds
# 4        5.01      US           clear sky
# 5       19.69      ZA    scattered clouds
# 6        3.94      ZA       broken clouds
# 7        8.01      CA     overcast clouds
# 8       13.82      AU       broken clouds
# 9        2.46      NZ           clear sky

# %%
# Change column orders
new_column_order = ["City", "Country","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     73.78        73           5
# 1         Conde      BR  -7.2597  -34.9075     74.66        94          75
# 2      Thompson      CA  55.7435  -97.8558     54.05        63          10
# 3    Bredasdorp      ZA -34.5322   20.0403     57.27        91          54
# 4        Laguna      US  38.4210 -121.4238     88.43        45           1
# 5   Port Alfred      ZA -33.5906   26.8910     64.96        88          32
# 6  Richards Bay      ZA -28.7830   32.0377     63.59        93          53
# 7        Inuvik      CA  68.3499 -133.7218     31.75        89          95
# 8     Busselton      AU -33.6500  115.3333     58.08        85          79
# 9       Mataura      NZ -46.1927  168.8643     48.47        37           4
#
#    Wind Speed Current Description
# 0       19.66           clear sky
# 1       12.66       broken clouds
# 2        2.10           clear sky
# 3        1.48       broken clouds
# 4        5.01           clear sky
# 5       19.69    scattered clouds
# 6        3.94       broken clouds
# 7        8.01     overcast clouds
# 8       13.82       broken clouds
# 9        2.46           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
